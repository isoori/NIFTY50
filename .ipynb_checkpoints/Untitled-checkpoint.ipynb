# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Final-50-stocks.csv')
df.head()
# Out:
#          DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO   TECHM  RELIANCE  \
# 0  2010-01-11     591.90  423.70  3792.50    6737.95  735.60   1093.20
# 1  2010-01-12     613.55  414.70  3781.90    5443.70  671.15    988.80
# 2  2010-02-11     599.05  433.85  3818.70    6735.25  724.55   1074.85
# 3  2010-02-12     622.75  426.05  3784.20    5368.40  676.35   1011.15
# 4  2010-03-11     609.60  434.70  3833.05    6858.65  732.50   1065.30
#
#    SHREECEM  SUNPHARMA  TATAMOTORS  ...    BPCL  BRITANNIA  ADANIPORTS  \
# 0   2116.10    2190.70     1170.60  ...  754.80     413.15         NaN
# 1   2094.10     448.65     1286.75  ...  697.95     410.30         NaN
# 2   2164.55    2190.45     1154.25  ...  772.75     413.60         NaN
# 3   2022.35     452.90     1320.15  ...  685.80     412.45         NaN
# 4   2261.40    2249.30     1185.55  ...  765.60     415.75         NaN
#
#    BAJAJFINSERV  BAJAJFINANCE  BHARTIARTL  AXISBANK  BAJAJ-AUTO  ASIANPAINT  \
# ...

# %%
dff = df.copy()

# %%
for i in range(1,df.shape[0]):
    for j in range(1,df.shape[1]):
        dff.iloc[i,j] = df.iloc[i,j] - df.iloc[i-1,j]

# %%
dff.drop(0,axis=0,inplace=True)

# %%
dff
# Out:
#             DATE  TATASTEEL  WIPRO   TITAN  ULTRACEMO   TECHM  RELIANCE  \
# 1     2010-01-12      21.65  -9.00  -10.60   -1294.25  -64.45   -104.40
# 2     2010-02-11     -14.50  19.15   36.80    1291.55   53.40     86.05
# 3     2010-02-12      23.70  -7.80  -34.50   -1366.85  -48.20    -63.70
# 4     2010-03-11     -13.15   8.65   48.85    1490.25   56.15     54.15
# 5     2010-03-12       4.95  -7.10 -136.60   -1315.20  -63.55    -59.40
# ...          ...        ...    ...     ...        ...     ...       ...
# 2706  2021-10-05     491.85  99.25  -16.10    5388.70  -18.25   -255.75
# 2707  2021-10-06    -101.90  28.30  283.50     306.55   74.40    256.80
# 2708  2021-10-08     259.15  49.60   60.55     764.50  258.15    -94.95
# 2709  2021-10-13     -19.30  68.75  738.00    -123.75   79.10    606.90
# 2710  2021-10-14      20.75  35.65   26.85      45.10   28.65      5.45
#
#       SHREECEM  SUNPHARMA  TATAMOTORS  ...   BPCL  BRITANNIA  ADANIPORTS  \
# ...

# %%
stacks = dff.columns.tolist()

# %%
new_df = pd.DataFrame()

# %%
for col in stacks :
    if col =='DATE':
        continue
    new_df.loc['Daily Average Change',col] = np.abs(dff[col]).sum(axis=0) / dff[col].notna().sum()

# %%
new_df
# Out:
#                       TATASTEEL      WIPRO      TITAN   ULTRACEMO      TECHM  \
# Daily Average Change   32.58548  18.626771  75.547841  255.957251  65.026937
#
#                        RELIANCE    SHREECEM  SUNPHARMA  TATAMOTORS        TCS  \
# Daily Average Change  56.053616  594.595221  42.446384   29.878118  84.375664
#
#                       ...       BPCL   BRITANNIA  ADANIPORTS  BAJAJFINSERV  \
# Daily Average Change  ...  34.255203  125.201882   25.594431    270.061494
#
#                       BAJAJFINANCE  BHARTIARTL   AXISBANK  BAJAJ-AUTO  \
# Daily Average Change    255.865535   18.141513  54.927509   92.556218
#
#                       ASIANPAINT        UPL
# Daily Average Change  111.979207  34.333299
#
# [1 rows x 46 columns]

# %%
new_df = new_df.T

# %%
new_df
# Out:
#               Daily Average Change
# TATASTEEL                32.585480
# WIPRO                    18.626771
# TITAN                    75.547841
# ULTRACEMO               255.957251
# TECHM                    65.026937
# RELIANCE                 56.053616
# SHREECEM                594.595221
# SUNPHARMA                42.446384
# TATAMOTORS               29.878118
# TCS                      84.375664
# SBIN                     72.182085
# NESTLEIND               291.744576
# NTPC                      5.246937
# M&M                      38.793653
# MARUTI                  212.970738
# ONGC                     17.064317
# POWERGRID                 8.241550
# JSWSTEEL                 44.392675
# KOTAKBANK                48.584262
# LT                       74.461310
# ICICIBANK                38.529114
# INDUSBANK                48.360461
# INFY                     94.029635
# IOC                      16.364945
# ITC                       9.721181
# HEROMOTOCO              109.863376
# ...

# %%
new_df['Daily Average Change'].max()
# Out:
# 843.4697601476014

# %%
new_df['Daily Average Change'].argmax()
# Out:
# 32
